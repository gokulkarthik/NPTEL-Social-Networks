# %% [markdown]
# ## Modelling road network of Indian cities

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph() #Undirected NULL graph
#G = nx.DiGraph() #Directed Graph
cities = ['Delhi', 'Trichy', 'Mumbai', 'Tuticorin', 'Chennai', 'Kochi', 'Hyderabad', 'Bangalore', 'Lucknow', 'Amaravati']
for city in cities:
    G.add_node(city)
nx.draw(G, with_labels=1)
plt.show()

# %%
import random as rd
costs = [rd.randint(50, 1000) for x in range(10) ]
print costs
print len(costs)
print "Edges : ", G.number_of_edges()
print "Nodes : ", G.number_of_nodes()
# Out:
# [727, 290, 386, 415, 454, 230, 648, 991, 119, 211]
# 10
# Edges :  0
# Nodes :  10

# %%
#Addding 10 edges to the graph
while(G.number_of_edges() != 10):
    city1 = rd.choice(G.nodes())
    city2 = rd.choice(G.nodes())
    wt = rd.choice(costs)#selecting random costs
    if city1 != city2 and G.has_edge(city1, city2) == 0:
        G.add_edge(city1, city2, weight = wt)
print G.edges()
nx.draw(G, with_labels=1)
plt.show()
# Out:
# [('Hyderabad', 'Delhi'), ('Hyderabad', 'Trichy'), ('Chennai', 'Bangalore'), ('Lucknow', 'Amaravati'), ('Mumbai', 'Delhi'), ('Delhi', 'Tuticorin'), ('Delhi', 'Trichy'), ('Amaravati', 'Tuticorin'), ('Amaravati', 'Trichy'), ('Bangalore', 'Trichy')]

# %%
pos = nx.spectral_layout(G)
nx.draw(G, pos)
plt.show()

# %%
pos = nx.spring_layout(G)
nx.draw(G, pos)
plt.show()

# %%
pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels=1)
plt.show()

# %%
#Visulaising edge weights
nx.draw(G, pos, with_labels=1)
nx.draw_networkx_edge_labels(G, pos)
plt.show()

# %%
print nx.is_connected(G)
# Out:
# False

# %%
for u in G.nodes():
    for v in G.nodes():
        print u, v, nx.has_path(G, u, v)
# Out:
# Hyderabad Hyderabad True
# Hyderabad Chennai True
# Hyderabad Lucknow True
# Hyderabad Mumbai True
# Hyderabad Delhi True
# Hyderabad Amaravati True
# Hyderabad Kochi False
# Hyderabad Tuticorin True
# Hyderabad Bangalore True
# Hyderabad Trichy True
# Chennai Hyderabad True
# Chennai Chennai True
# Chennai Lucknow True
# Chennai Mumbai True
# Chennai Delhi True
# Chennai Amaravati True
# Chennai Kochi False
# Chennai Tuticorin True
# Chennai Bangalore True
# Chennai Trichy True
# Lucknow Hyderabad True
# Lucknow Chennai True
# Lucknow Lucknow True
# Lucknow Mumbai True
# Lucknow Delhi True
# Lucknow Amaravati True
# Lucknow Kochi False
# Lucknow Tuticorin True
# Lucknow Bangalore True
# Lucknow Trichy True
# Mumbai Hyderabad True
# Mumbai Chennai True
# Mumbai Lucknow True
# Mumbai Mumbai True
# Mumbai Delhi True
# Mumbai Amaravati True
# Mumbai Kochi False
# Mumbai Tuticorin True
# Mumbai Bangalore True
# Mumbai Trichy True
# Delhi Hyderabad True
# Delhi Chennai True
# Delhi Lucknow True
# Delhi Mumbai True
# Delhi Delhi True
# Delhi Amaravati True
# Delhi Kochi False
# Delhi Tuticorin True
# Delhi Bangalore True
# Delhi Trichy True
# Amaravati Hyderabad True
# Amaravati Chennai True
# Amaravati Lucknow True
# Amaravati Mumbai True
# Amaravati Delhi True
# Amaravati Amaravati True
# Amaravati Kochi False
# Amaravati Tuticorin True
# Amaravati Bangalore True
# Amaravati Trichy True
# Kochi Hyderabad False
# Kochi Chennai False
# Kochi Lucknow False
# Kochi Mumbai False
# Kochi Delhi False
# Kochi Amaravati False
# Kochi Kochi True
# Kochi Tuticorin False
# Kochi Bangalore False
# Kochi Trichy False
# Tuticorin Hyderabad True
# Tuticorin Chennai True
# Tuticorin Lucknow True
# Tuticorin Mumbai True
# Tuticorin Delhi True
# Tuticorin Amaravati True
# Tuticorin Kochi False
# Tuticorin Tuticorin True
# Tuticorin Bangalore True
# Tuticorin Trichy True
# Bangalore Hyderabad True
# Bangalore Chennai True
# Bangalore Lucknow True
# Bangalore Mumbai True
# Bangalore Delhi True
# Bangalore Amaravati True
# Bangalore Kochi False
# Bangalore Tuticorin True
# Bangalore Bangalore True
# Bangalore Trichy True
# Trichy Hyderabad True
# Trichy Chennai True
# Trichy Lucknow True
# Trichy Mumbai True
# Trichy Delhi True
# Trichy Amaravati True
# Trichy Kochi False
# Trichy Tuticorin True
# Trichy Bangalore True
# Trichy Trichy True

# %%
#Refer networkx.github.io documentation for dijikstra functions

# %%
#write a module to create the road network
def create_network(cities, costs, numberOfLinks):
    G = nx.Graph()
    for city in cities:
        G.add_node(city)
    while(G.number_of_edges() < numberOfLinks):
        city1 = rd.choice(G.nodes())
        city2 = rd.choice(G.nodes())
        if city1 != city2 and G.has_edge(city1, city2) == 0:
            G.add_edge(city1, city2, weight = rd.choice(costs))
    return G
G = create_network(cities, costs, 8)
print G.number_of_edges()
pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels=1)
nx.draw_networkx_edge_labels(G, pos)
plt.show()
# Out:
# 8

# %%
9999999999
# Out:
# 9999999999

# %%
print nx.dijkstra_path(G, 'Delhi', 'Trichy')
print nx.dijkstra_path_length(G, 'Delhi', 'Trichy')
# Out:
# ---------------------------------------------------------------------------
# NetworkXNoPath                            Traceback (most recent call last)
# <ipython-input-46-bb95178f994e> in <module>()
# ----> 1 print nx.dijkstra_path(G, 'Delhi', 'Trichy')
#       2 print nx.dijkstra_path_length(G, 'Delhi', 'Trichy')
#
# /home/gokul/anaconda2/lib/python2.7/site-packages/networkx/algorithms/shortest_paths/weighted.pyc in dijkstra_path(G, source, target, weight)
#      81     except KeyError:
#      82         raise nx.NetworkXNoPath(
# ---> 83             "node %s not reachable from %s" % (source, target))
#      84
#      85
#
# NetworkXNoPath: node Delhi not reachable from Trichy

# %%
print nx.dijkstra_path(G, 'Tuticorin', 'Hyderabad')# source and destination
print nx.dijkstra_path_length(G,'Tuticorin', 'Hyderabad')
# Out:
# ['Tuticorin', 'Delhi', 'Hyderabad']
# 1113

# %%
#single source shorest path
print nx.single_source_dijkstra_path(G, 'Tuticorin')# source
print nx.single_source_dijkstra_path_length(G,'Tuticorin')
# Out:
# {'Hyderabad': ['Tuticorin', 'Delhi', 'Hyderabad'], 'Chennai': ['Tuticorin', 'Delhi', 'Chennai'], 'Lucknow': ['Tuticorin', 'Lucknow'], 'Delhi': ['Tuticorin', 'Delhi'], 'Kochi': ['Tuticorin', 'Delhi', 'Chennai', 'Kochi'], 'Tuticorin': ['Tuticorin']}
# {'Hyderabad': 1113, 'Chennai': 616, 'Lucknow': 454, 'Delhi': 386, 'Kochi': 735, 'Tuticorin': 0}

# %% [markdown]
# ## Connecting Trichy and Delhi

# %%
x = [0]
y = [99999999]
cnt  = 0
def make_random_road(cnt):
    cnt = cnt + 1
    city1 = rd.choice(G.nodes())
    city2 = rd.choice(G.nodes())
    wt = rd.choice(costs)
    G.add_edge(city1, city2, weight = wt)
    try:
        distance = nx.dijkstra_path_length(G, 'Trichy', 'Delhi')
        x.append(cnt)
        y.append(distance)
        return cnt
    except:
        print cnt, "Still no path...."
        x.append(cnt)
        y.append(99999999)
        cnt += 1
        make_random_road(cnt)

# %%
make_random_road()

# %%
print nx.dijkstra_path(G, 'Delhi', 'Trichy')
print nx.dijkstra_path_length(G, 'Delhi', 'Trichy')
# Out:
# ['Delhi', 'Chennai', 'Trichy']
# 349

# %%
plt.plot(x, y)
plt.axis([0,5,0,10000000])
plt.show()
